# %% [markdown]
# ## `課題1：上記チュートリアルを一通り実行してみましょう`

# %% [markdown]
# #### `チュートリアル`

# %% [markdown]
# #### `手順1:Tamagotchiクラスを定義`
# #### コンストラクタ(初期化メソッド)として、下記4つのステータス（インスタンス変数）を設定
# - `name`（名前）:たまごっち
# - `age`（年齢）:0
# - `hunger`（空腹度）:5
# - `happiness`（幸福度）:5
# - `weight`（体重）:1
# - インスタンスが生成された時に「〇〇が孵化しました！」と表示させる

# %%
class Tamagotchi:
    def __init__(self, name):
        self.name = name
        self.age = 0
        self.hunger = 5
        self.happiness = 5
        self.weight = 1
        print(f'{self.name}が孵化しました！')

# %%
tama = Tamagotchi('べびっち')
print({'age':tama.age,
    'hunger':tama.hunger,
    'happiness':tama.happiness,
    'weight':tama.weight})
# Out:
# べびっちが孵化しました！
# {'age': 0, 'hunger': 5, 'happiness': 5, 'weight': 1}

# %% [markdown]
# #### `手順2：Tamagotchiクラスの基本行動`
# ##### 基本行動(メソッド)として、下記3つを設定
# - 基本行動を実行した時に擬音を表示し、ステータスを変化させます
#     - `eat`（喰う）
#     - `sleep`（寝る）
#     - `play`（遊ぶ）
# - 時間進行させた時に進行時間を表示し、ステータスを変化させます
#     - `update_time` (時間を進める)
#     - 引数 `hour` を設定し、任意の時間経過ができるようにする（単位：時間）

# %%
class Tamagotchi:
    def __init__(self, name):
        self.name = name
        self.age = 0
        self.hunger = 5
        self.happiness = 5
        self.weight = 1
        print(f"{self.name}が孵化しました！")

    def eat(self):
        print(f"{self.name}にご飯を与えました")
        print("もぐもぐ!")
        self.age += 0
        self.hunger += 5
        self.happiness += 5
        self.weight += 2

    def sleep(self):
        print(f"{self.name}は眠りにつきました")
        print("ぐーぐー…")
        self.age += 0
        self.hunger -= 1
        self.happiness += 1
        self.weight += 0

    def play(self):
        print(f"{self.name}は遊びました")
        print("わいわい!!")
        self.age += 0
        self.hunger -= 3
        self.happiness += 1
        self.weight -= 1

    def update_time(self, hour):
        print(f"{hour}時間経過しました")
        self.age += 1 * hour
        self.hunger -= 2 * hour
        self.happiness -= 3 * hour
        self.weight += 1 * hour

def main():
    tama = Tamagotchi("たまごっち")

    tama.eat()
    tama.sleep()
    tama.play()
    tama.update_time(hour=1)
    print(
        f"""
          名前:{self.name}
          年齢:{self.age}
          満腹度:{self.hunger}
          体重:{self.weight}
          {'-' * 50}
          """
    )


if __name__ == "__main__":
    main()
# Out:
# たまごっちが孵化しました！
# たまごっちにご飯を与えました
# もぐもぐ!
# たまごっちは眠りにつきました
# ぐーぐー…
# たまごっちは遊びました
# わいわい!!
# 1時間経過しました
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/daisuke/Desktop/VSCode_data/code4biz/コードを書く会/第13回/Tamagotchi.ipynb セル 6 in <cell line: 59>()
#      <a href='vscode-notebook-cell:/Users/daisuke/Desktop/VSCode_data/code4biz/%E3%82%B3%E3%83%BC%E3%83%88%E3%82%99%E3%82%92%E6%9B%B8%E3%81%8F%E4%BC%9A/%E7%AC%AC13%E5%9B%9E/Tamagotchi.ipynb#W2sZmlsZQ%3D%3D?line=47'>48</a>     print(
#      <a href='vscode-notebook-cell:/Users/daisuke/Desktop/VSCode_data/code4biz/%E3%82%B3%E3%83%BC%E3%83%88%E3%82%99%E3%82%92%E6%9B%B8%E3%81%8F%E4%BC%9A/%E7%AC%AC13%E5%9B%9E/Tamagotchi.ipynb#W2sZmlsZQ%3D%3D?line=48'>49</a>         f"""
# ...

# %% [markdown]
# `エラーの原因は、main関数内のprint文でselfという変数を参照していることにあります。クラスのメソッド内でなければ、selfは使用できません。selfはクラス内でインスタンスを参照する際に使われるキーワードであり、ここではTamagotchiのインスタンスtamaを参照するべきです。`

# %%
class Tamagotchi:
    def __init__(self, name):
        self.name = name
        self.age = 0
        self.hunger = 5
        self.happiness = 5
        self.weight = 1
        print(f"{self.name}が孵化しました！")

    def eat(self):
        print(f"{self.name}にご飯を与えました")
        print("もぐもぐ!")
        self.age += 0
        self.hunger += 5
        self.happiness += 5
        self.weight += 2

    def sleep(self):
        print(f"{self.name}は眠りにつきました")
        print("ぐーぐー…")
        self.age += 0
        self.hunger -= 1
        self.happiness += 1
        self.weight += 0

    def play(self):
        print(f"{self.name}は遊びました")
        print("わいわい!!")
        self.age += 0
        self.hunger -= 3
        self.happiness += 1
        self.weight -= 1

    def update_time(self, hour):
        print(f"{hour}時間経過しました")
        self.age += (1 * hour)
        self.hunger -= (2 * hour)
        self.happiness -= (3 * hour)
        self.weight += (1 * hour)

def main():
    tama = Tamagotchi("たまごっち")

    tama.eat()
    tama.sleep()
    tama.play()
    tama.update_time(hour=1)
    print(
        f"""名前:{tama.name}\n年齢:{tama.age}\n満腹度:{tama.hunger}\n幸福度:{tama.happiness}\n体重:{tama.weight}\n{'-' * 50}
    """
    )


if __name__ == "__main__":
    main()
# Out:
# たまごっちが孵化しました！
# たまごっちにご飯を与えました
# もぐもぐ!
# たまごっちは眠りにつきました
# ぐーぐー…
# たまごっちは遊びました
# わいわい!!
# 1時間経過しました
# 名前:たまごっち
# 年齢:1
# 満腹度:4
# 幸福度:9
# 体重:3
# --------------------------------------------------

# %% [markdown]
# #### `手順3：ステータスを表示する特殊メソッド(__str__メソッド)を用いてステータスを表示させましょう`

# %% [markdown]
# Pythonでは、特殊メソッドと呼ばれる特定の名前を持つメソッドをクラスに定義することで、そのクラスのオブジェクトに対して様々な組み込み関数や演算子の動作をカスタマイズすることができます。この特殊メソッドの一つに __str__ があります。
#
# __str__ メソッドは、クラスのインスタンスを人間が読むことを目的とした文字列に変換するためのメソッドです。このメソッドを定義すると、クラスのインスタンスを print() 関数で出力したり、str() 関数で文字列に変換したりしたときに、__str__ メソッドが返す値が使用されます。
#
# __str__メソッドは通常、以下のように定義します：

# %%
class MyClass:
    def __init__(self, x):
        self.x = x

    def __str__(self):
        return f"MyClass instance, x = {self.x}"

# %% [markdown]
# 上記の例では、MyClass の __str__ メソッドが f"MyClass instance, x = {self.x}" という文字列を返します。このため、MyClass のインスタンスを print() で出力したり str() で文字列に変換したりすると、そのインスタンスの x 属性が含まれた文字列が得られます。

# %%
my_instance = MyClass(10)
print(my_instance)  # Output: MyClass instance, x = 10
# Out:
# MyClass instance, x = 10

# %% [markdown]
# この __str__ メソッドを使って、クラスのインスタンスが保持するデータを任意のフォーマットの文字列として表現することができます。

# %%
import textwrap

class Tamagotchi:
    
    def __init__(self, name):
        self.name = name
        self.age = 0
        self.hunger = 5
        self.happiness = 5
        self.weight = 1
        print(f"{self.name}が孵化しました！")

    def eat(self):
        print(f"{self.name}にご飯を与えました")
        print("もぐもぐ!")
        self.age += 0
        self.hunger += 5
        self.happiness += 5
        self.weight += 2

    def sleep(self):
        print(f"{self.name}は眠りにつきました")
        print("ぐーぐー…")
        self.age += 0
        self.hunger -= 1
        self.happiness += 1
        self.weight += 0

    def play(self):
        print(f"{self.name}は遊びました")
        print("わいわい!!")
        self.age += 0
        self.hunger -= 3
        self.happiness += 1
        self.weight -= 1

    def update_time(self, hour):
        print(f"{hour}時間経過しました")
        self.age += (1 * hour)
        self.hunger -= (2 * hour)
        self.happiness -= (3 * hour)
        self.weight += (1 * hour)

    def __str__(self):
        self.status = textwrap.dedent(f'''名前:{self.name}\n年齢:{self.age}\n満腹度:{self.hunger}\n幸福度:{self.happiness}\n体重:{self.weight}\n{'-' * 50}
    ''')
        return self.status

def main():
    tama = Tamagotchi("たまごっち")
    print(tama)

    tama.eat()
    tama.sleep()
    tama.play()
    tama.update_time(hour=1)
    print(tama)


if __name__ == "__main__":
    main()
# Out:
# たまごっちが孵化しました！
# 名前:たまごっち
# 年齢:0
# 満腹度:5
# 幸福度:5
# 体重:1
# --------------------------------------------------
#
# たまごっちにご飯を与えました
# もぐもぐ!
# たまごっちは眠りにつきました
# ぐーぐー…
# たまごっちは遊びました
# わいわい!!
# 1時間経過しました
# 名前:たまごっち
# 年齢:1
# 満腹度:4
# 幸福度:9
# 体重:3
# --------------------------------------------------

# %% [markdown]
# #### `手順4：Tamaotchiクラスの継承1`
# ##### Tamagotchiクラスを親クラスとして、Babyという子クラスを定義します

# %% [markdown]
# Pythonの継承とは、あるクラス（親クラスや基底クラスとも呼ばれます）が持っている属性やメソッドを別のクラス（子クラスや派生クラスとも呼ばれます）が受け継ぐことです。継承を使用すると、すでに存在するクラスを基に新たなクラスを作成することができ、コードの再利用性が向上します。
#
# クラスの定義時に、カッコ内に親クラスを記述することで、その親クラスを継承します。以下は基本的な継承の例です：

# %%
class Parent:
    def method(self):
        print("Parent method")

class Child(Parent):
    pass

c = Child()
c.method()  # Output: Parent method
# Out:
# Parent method

# %% [markdown]
# この例では、ChildクラスはParentクラスを継承しているため、ParentクラスのmethodメソッドをChildクラスのインスタンスから呼び出すことができます。

# %% [markdown]
# ---

# %% [markdown]
# 下記コードでは、Tamagotchiクラスを継承したBabyクラスを定義しています。これにより、BabyクラスはTamagotchiクラスの全てのメソッド（__init__, eat, sleep, play, update_time, __str__）と属性（name, age, hunger, happiness, weight）を継承します。
#
# さらに、Babyクラスには新たにcryメソッドを定義しています。このメソッドはBabyクラス独自のメソッドで、Tamagotchiクラスには存在しません。これにより、Babyクラスのインスタンスからはcryメソッドを呼び出すことができますが、Tamagotchiクラスのインスタンスからは呼び出すことはできません。
#
# 継承を利用することで、既存のクラスを基に新たなクラスを容易に作成することができ、また、コードの修正や拡張も容易になります。

# %%
class Baby(Tamagotchi):

    def cry(self):
        print(f'{self.name}が泣いているよ')
        print('おんぎゃー!!!!')
        self.age += 0
        self.hunger -= 1
        self.happiness -= 1
        self.weight += 0

def main():
    baby = Baby('べびっち')
    print(baby)

    baby.cry()
    print(baby)

    baby.eat()
    baby.sleep()
    baby.update_time(hour=1)
    print(baby)

if __name__ =='__main__':
    main()
# Out:
# べびっちが孵化しました！
# 名前:べびっち
# 年齢:0
# 満腹度:5
# 幸福度:5
# 体重:1
# --------------------------------------------------
#
# べびっちが泣いているよ
# おんぎゃー!!!!
# 名前:べびっち
# 年齢:0
# 満腹度:4
# 幸福度:4
# 体重:1
# --------------------------------------------------
#
# べびっちにご飯を与えました
# もぐもぐ!
# べびっちは眠りにつきました
# ぐーぐー…
# 1時間経過しました
# 名前:べびっち
# 年齢:1
# 満腹度:6
# 幸福度:7
# 体重:4
# --------------------------------------------------

# %% [markdown]
# #### `手順5：Tamaotchiクラスの継承2（メソッドオーバーライド）`
# ##### Tamagotchiクラスを親クラスとして、Adultという子クラスを定義します

# %% [markdown]
# メソッドのオーバーライドとは、子クラスが親クラスで定義されたメソッドを新たに定義し直すことを言います。これにより、同名のメソッドが呼び出されたとき、子クラスで定義した新たなメソッドの振る舞いが優先されます。これにより、親クラスのメソッドを子クラスの要件に合わせて修正・拡張することができます。
#
# あなたのコードでは、Tamagotchiクラスを継承したAdultクラスが定義されています。このAdultクラスでは、__init__メソッドと__str__メソッドがオーバーライドされています。
#
# __init__メソッドでは、Adultクラスの初期化処理が記述されています。Adultクラスでは新たにdrunkness（酔い度）という属性が追加されており、__init__メソッド内でこの属性の初期化が行われています。
#
# また、__str__メソッドもオーバーライドされており、Tamagotchiクラスのものとは異なる情報（具体的には酔い度）を文字列として表示するようになっています。
#
# さらに、Adultクラスにはdrink_alcholという新たなメソッドが定義されています。これは、AdultクラスがTamagotchiクラスから継承したメソッドに加えて追加された新たなメソッドです。
#
# main関数では、Adultクラスのインスタンスが作成され、そのインスタンスを使って各種メソッドが呼び出されています。具体的には、drink_alcholメソッドとeatメソッドが3回ずつ、その後にupdate_timeメソッドが1回呼び出され、その都度状態が表示されています。
#
# このように、Pythonの継承とオーバーライドを使うことで、既存のクラスを基に新たなクラスを作成し、それぞれのクラスに適した振る舞いを持たせることができます。

# %%
class Adult(Tamagotchi):
    def __init__(self, name):
        self.name = name
        self.age = 18
        self.hunger = 5
        self.happiness = 5
        self.weight = 50
        self.drunkness = 0
        print(f'大人になり{self.name}になりました')
    
    def drink_alchol(self):
        print(f'{self.name}は飲んだくれています')
        print('酒持ってこーい!')
        self.age += 0
        self.hunger += 3
        self.happiness += 3
        self.weight += 3
        self.drunkness += 20
    
    def __str__(self):
        self.status = textwrap.dedent(f'''名前:{self.name}\n年齢:{self.age}\n満腹度:{self.hunger}\n幸福度:{self.happiness}\n体重:{self.weight}\n酔度{self.drunkness}\n{'-' * 50}
    ''')
        return self.status

def main():
    adult = Adult('おやじっち')
    adult.age = 60
    print(adult)

    for i in range(3):
        print(f'{i + 1}回目')
        adult.drink_alchol()
        adult.eat()
    adult.update_time(hour=7)
    print(adult)

if __name__ == '__main__':
    main()
# Out:
# 大人になりおやじっちになりました
# 名前:おやじっち
# 年齢:60
# 満腹度:5
# 幸福度:5
# 体重:50
# 酔度0
# --------------------------------------------------
#
# 1回目
# おやじっちは飲んだくれています
# 酒持ってこーい!
# おやじっちにご飯を与えました
# もぐもぐ!
# 2回目
# おやじっちは飲んだくれています
# 酒持ってこーい!
# おやじっちにご飯を与えました
# もぐもぐ!
# 3回目
# おやじっちは飲んだくれています
# 酒持ってこーい!
# おやじっちにご飯を与えました
# もぐもぐ!
# 7時間経過しました
# 名前:おやじっち
# 年齢:67
# 満腹度:15
# 幸福度:8
# 体重:72
# 酔度60
# --------------------------------------------------

# %%
import textwrap

class Tamagotchi:
    
    def __init__(self, name):
        self.name = name
        self.age = 0
        self.hunger = 5
        self.happiness = 5
        self.weight = 1
        print(f"{self.name}が孵化しました！")

    def eat(self):
        print(f"{self.name}にご飯を与えました")
        print("もぐもぐ!")
        self.age += 0
        self.hunger += 5
        self.happiness += 5
        self.weight += 2

    def sleep(self):
        print(f"{self.name}は眠りにつきました")
        print("ぐーぐー…")
        self.age += 0
        self.hunger -= 1
        self.happiness += 1
        self.weight += 0

    def play(self):
        print(f"{self.name}は遊びました")
        print("わいわい!!")
        self.age += 0
        self.hunger -= 3
        self.happiness += 1
        self.weight -= 1

    def update_time(self, hour):
        print(f"{hour}時間経過しました")
        self.age += (1 * hour)
        self.hunger -= (2 * hour)
        self.happiness -= (3 * hour)
        self.weight += (1 * hour)

    def __str__(self):
        self.status = textwrap.dedent(f'''名前:{self.name}\n年齢:{self.age}\n満腹度:{self.hunger}\n幸福度:{self.happiness}\n体重:{self.weight}\n{'-' * 50}
    ''')
        return self.status

class Baby(Tamagotchi):

    def cry(self):
        print(f'{self.name}が泣いているよ')
        print('おんぎゃー!!!!')
        self.age += 0
        self.hunger -= 1
        self.happiness -= 1
        self.weight += 0

class Adult(Tamagotchi):
    def __init__(self, name):
        self.name = name
        self.age = 18
        self.hunger = 5
        self.happiness = 5
        self.weight = 50
        self.drunkness = 0
        print(f'大人になり{self.name}になりました')
    
    def drink_alchol(self):
        print(f'{self.name}は飲んだくれています')
        print('酒持ってこーい!')
        self.age += 0
        self.hunger += 3
        self.happiness += 3
        self.weight += 3
        self.drunkness += 20
    
    def __str__(self):
        self.status = textwrap.dedent(f'''名前:{self.name}\n年齢:{self.age}\n満腹度:{self.hunger}\n幸福度:{self.happiness}\n体重:{self.weight}\n酔度{self.drunkness}\n{'-' * 50}
    ''')
        return self.status

def main():
    tama = Tamagotchi("たまごっち")
    print(tama)

    tama.eat()
    tama.sleep()
    tama.play()
    tama.update_time(hour=1)
    print(tama)


if __name__ == "__main__":
    main()

# %% [markdown]
# #### `手順6：べびっち’にdrink_alcholを行ってみましょう`
# ##### - `Baby`クラスには`drink_alchol`メソッドは無いのでエラーが出ます
# ##### - `AttributeError: 'Baby' object has no attribute 'drink_alchol'`

# %%
def main():

    baby = Baby('べびっち')
    print(baby)

    baby.drink_alchol()
    print(baby)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/daisuke/Desktop/VSCode_data/code4biz/コードを書く会/第13回/Tamagotchi.ipynb セル 28 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/Users/daisuke/Desktop/VSCode_data/code4biz/%E3%82%B3%E3%83%BC%E3%83%88%E3%82%99%E3%82%92%E6%9B%B8%E3%81%8F%E4%BC%9A/%E7%AC%AC13%E5%9B%9E/Tamagotchi.ipynb#X42sZmlsZQ%3D%3D?line=6'>7</a>     print(baby)
#       <a href='vscode-notebook-cell:/Users/daisuke/Desktop/VSCode_data/code4biz/%E3%82%B3%E3%83%BC%E3%83%88%E3%82%99%E3%82%92%E6%9B%B8%E3%81%8F%E4%BC%9A/%E7%AC%AC13%E5%9B%9E/Tamagotchi.ipynb#X42sZmlsZQ%3D%3D?line=8'>9</a> if __name__ == "__main__":
# ---> <a href='vscode-notebook-cell:/Users/daisuke/Desktop/VSCode_data/code4biz/%E3%82%B3%E3%83%BC%E3%83%88%E3%82%99%E3%82%92%E6%9B%B8%E3%81%8F%E4%BC%9A/%E7%AC%AC13%E5%9B%9E/Tamagotchi.ipynb#X42sZmlsZQ%3D%3D?line=9'>10</a>     main()
#
# ...

# %% [markdown]
# #### `課題2： たまごっちに指示（餌やり、寝つけ、遊ばせる）できるようにしてみましょう`
# - 例) `input`()関数で指示を与える

# %%
import textwrap

class Tamagotchi:

    def __init__(self, name):
        self.name = name
        self.age = 0
        self.hunger = 5
        self.happiness = 5
        self.weight = 1
        print(f"{self.name}が孵化しました！")

    def eat(self):
        print(f"{self.name}にご飯を与えました")
        print("もぐもぐ!")
        self.age += 0
        self.hunger += 5
        self.happiness += 5
        self.weight += 2

    def sleep(self):
        print(f"{self.name}は眠りにつきました")
        print("ぐーぐー…")
        self.age += 0
        self.hunger -= 1
        self.happiness += 1
        self.weight += 0

    def play(self):
        print(f"{self.name}は遊びました")
        print("わいわい!!")
        self.age += 0
        self.hunger -= 3
        self.happiness += 1
        self.weight -= 1

    def update_time(self, hour):
        print(f"{hour}時間経過しました")
        self.age += (1 * hour)
        self.hunger -= (2 * hour)
        self.happiness -= (3 * hour)
        self.weight += (1 * hour)

    def __str__(self):
        self.status = textwrap.dedent(f'''名前:{self.name}\n年齢:{self.age}\n満腹度:{self.hunger}\n幸福度:{self.happiness}\n体重:{self.weight}\n{'-' * 50}
    ''')
        return self.status

class Baby(Tamagotchi):

    # Tamagotchiクラスを継承
    def cry(self):
        print(f'{self.name}が泣いているよ')
        print('おんぎゃー!!!!')
        self.age += 0
        self.hunger -= 1
        self.happiness -= 1
        self.weight += 0

class Adult(Tamagotchi):
    
    # オーバーライド
    def __init__(self, name):
        self.name = name
        self.age = 18
        self.hunger = 5
        self.happiness = 5
        self.weight = 50
        self.drunkness = 0
        print(f'大人になり{self.name}になりました')
    
    def drink_alchol(self):
        print(f'{self.name}は飲んだくれています')
        print('酒持ってこーい!')
        self.age += 0
        self.hunger += 3
        self.happiness += 3
        self.weight += 3
        self.drunkness += 20
    
    def __str__(self):
        self.status = textwrap.dedent(f'''名前:{self.name}\n年齢:{self.age}\n満腹度:{self.hunger}\n幸福度:{self.happiness}\n体重:{self.weight}\n酔度{self.drunkness}\n{'-' * 50}
    ''')
        return self.status

def main():
    tama = Tamagotchi("たまごっち")
    print(tama)

    # ユーザーインタラクションを追加
    while True:
        print("■コマンド一覧")
        print("1. ごはんをあげる")
        print("2. 寝かせる")
        print("3. 遊ぶ")
        print("4. 時間を進める")
        print("5. ステータスを確認")
        print("6. 終了")

        choice = input("何をしますか？（1-6から選んで数字を入力してください）: ")

        if choice == "1":
            tama.eat()
        elif choice == "2":
            tama.sleep()
        elif choice == "3":
            tama.play()
        elif choice == "4":
            hour = int(input("何時間経過させますか？（時間を数字で入力してください）： "))
            tama.update_time(hour)
        elif choice == "5":
            print(tama)
        elif choice == "6":
            break
        else:
            print("無効な選択です。もう一度お試しください。")
        print("\n")
        print("-" * 50)

if __name__ == "__main__":
    main()

# %% [markdown]
# #### `課題3：基本ステータス（age、hunger、happiness、weightなど）には取り得る数値範囲があります`
# - 設計仕様＞基本ステータス一覧参照
# - インスタンスメソッドに範囲外となった時の処理を追加しましょう
#
# - 例
#     -  `hunger`が0になるとゲームオーバー
#     - `happiness`が0になるとゲームオーバー
